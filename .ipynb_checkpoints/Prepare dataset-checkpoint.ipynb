# %%
import csv
import math
import re
import sys
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tweepy
from bs4 import BeautifulSoup
#from keras.layers import Dense, Flatten, LSTM
#from keras.layers.embeddings import Embedding
#from keras.models import Sequential
#from keras.preprocessing import sequence
from nltk.corpus import stopwords   # Import the stop word list
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from textblob import TextBlob
import datetime as dt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import 4 months twitter data

# %%
#with open('tweetwise_data/tweets_raw.txt','r') as f:
#    text = f.read()

# %%
#f = open('C:\Users\kapilesh\Desktop\224 bitcoin project\tweetwise data\tweets_raw.txt','r')
#text = f.read()
with open('C:/Users/kapilesh/Desktop/224 bitcoin project/tweetwise data/tweets_raw.txt','r',encoding="utf8") as f:
    text = f.read()

# %%
text1 = text.split("\n")

# %%
list1  = []
for i in text1:
    m = i.split("||")
    #print(m)
    if len(m) == 4:
        list1.append(m)

# %%
len(list1)
# Out:
# 1047175

# %%
df = pd.DataFrame(list1)

# %%
df.head()
# Out:
#                 0                                                  1  \
# 0     CoinbaseBot  The price of bitcoin on @coinbase is now 673.6...
# 1  rjy6utdyi6ruth  RT @RedditBTC: Iceland: Few days before electi...
# 2   BitcoinWorker  Easy and easy and easy mining #bitcoin with cl...
# 3     CoinAcademy  Bitcoin based social media community, Yours, c...
# 4   FreeCashGifts  RT @BitcoinMagazine: With TumbleBit, #Bitcoin ...
#
#                      2 3
# 0  2016-10-27T00:00:41
# 1  2016-10-27T00:00:39
# 2  2016-10-27T00:00:30
# 3  2016-10-27T00:00:27
# 4  2016-10-27T00:00:22

# %%
df.drop([0,3], axis=1, inplace=True)

# %%
df.columns = ['Text','Date']

# %%
df.dtypes
# Out:
# Text    object
# Date    object
# dtype: object

# %%
df.head()
# Out:
#                                                 Text                 Date
# 0  The price of bitcoin on @coinbase is now 673.6...  2016-10-27T00:00:41
# 1  RT @RedditBTC: Iceland: Few days before electi...  2016-10-27T00:00:39
# 2  Easy and easy and easy mining #bitcoin with cl...  2016-10-27T00:00:30
# 3  Bitcoin based social media community, Yours, c...  2016-10-27T00:00:27
# 4  RT @BitcoinMagazine: With TumbleBit, #Bitcoin ...  2016-10-27T00:00:22

# %%
df['Date'] = df['Date'].apply(lambda x: x.split('T'))
df = df[df['Date'].map(len) == 2]

# %%
df['Date']=df['Date'].apply(lambda x: x[0])

# %%
df = df.dropna()

# %%
date_list = ['2016-10-27', '2016-10-28', '2016-10-29', '2016-10-30',
       '2016-10-31', '2016-11-01', '2016-11-02', '2016-11-03',
       '2016-11-04', '2016-11-05', '2016-11-06',
       '2016-11-07',  '2016-11-08',
       '2016-11-09', 
       '2016-11-10',
       '2016-11-11', '2016-11-12',  '2016-11-13',
       '2016-11-14', '2016-11-15', '2016-11-16', '2016-11-17',
       '2016-11-18', '2016-11-19',
       '2016-11-20',  '2016-11-21',  '2016-11-22','2016-11-23','2016-11-24','2016-11-25','2016-11-26', '2016-11-27','2016-11-28', '2016-11-29','2016-11-30',
       '2016-12-01',
       '2016-12-02',  '2016-12-03', '2016-12-04', 
       '2016-12-05', '2016-12-06', 
       '2016-12-07', '2016-12-08','2016-12-09','2016-12-10', '2016-12-11','2016-12-12', '2016-12-13', '2016-12-14',
       '2016-12-15', '2016-12-16', '2016-12-17', '2016-12-18','2016-12-19', '2016-12-20',
       '2016-12-21','2016-12-22', '2016-12-23','2016-12-24', '2016-12-25', '2016-12-26',
       '2016-12-27', '2016-12-28', '2016-12-29',
       '2016-12-30', '2016-12-31',
       '2017-01-01',  '2017-01-02','2017-01-03', '2017-01-04',  '2017-01-05', '2017-01-06',
       '2017-01-07', '2017-01-08', '2017-01-09', '2017-01-10',
       '2017-01-11','2017-01-12', '2017-01-13', '2017-01-14','2017-01-15',
       '2017-01-16',  '2017-01-17', '2017-01-18', '2017-01-19', '2017-01-20', '2017-01-21',  '2017-01-22', '2017-01-23', '2017-01-24','2017-01-25', '2017-01-26',
       '2017-01-27',  '2017-01-28', '2017-01-29', '2017-01-30',
       '2017-01-31',  '2017-02-01', '2017-02-02', '2017-02-03', '2017-02-04', '2017-02-05',  '2017-02-06', '2017-02-07', 
       '2017-02-08', '2017-02-09',  '2017-02-10', '2017-02-11', '2017-02-12', '2017-02-13', '2017-02-14', '2017-02-15', '2017-02-16', '2017-02-17',
       '2017-02-18', '2017-02-19', 
       '2017-02-20', '2017-02-21', '2017-02-22']

# %%
df = df[df['Date'].isin(date_list)]

# %%
df['Date'] = df['Date'].apply(lambda x: dt.datetime.strptime(x,'%Y-%m-%d') )
df['Date'] = df['Date'].dt.date

# %%
df.head() # final data with relevant date
# Out:
#                                                 Text        Date
# 0  The price of bitcoin on @coinbase is now 673.6...  2016-10-27
# 1  RT @RedditBTC: Iceland: Few days before electi...  2016-10-27
# 2  Easy and easy and easy mining #bitcoin with cl...  2016-10-27
# 3  Bitcoin based social media community, Yours, c...  2016-10-27
# 4  RT @BitcoinMagazine: With TumbleBit, #Bitcoin ...  2016-10-27

# %% [markdown]
# ## Import Bitcoin price data

# %%
#btc = pd.read_csv('coindesk-bpi-USD-close_data-2010-07-17_2018-04-06.csv')

# %%
btc = pd.read_csv(r'C:\Users\kapilesh\Desktop\224 bitcoin project\coindesk-bpi-USD-close_data-2010-07-17_2018-03-06.csv')

# %%
btc.head()
# Out:
#                   Date  Close Price
# 0  2010-07-18 00:00:00         0.09
# 1  2010-07-19 00:00:00         0.08
# 2  2010-07-20 00:00:00         0.07
# 3  2010-07-21 00:00:00         0.08
# 4  2010-07-22 00:00:00         0.05

# %%
btc= btc[btc['Date']!='This data was produced from the CoinDesk price page.']
btc= btc[btc['Date']!='http://www.coindesk.com/price/']

# %%
btc['Date'] = btc['Date'].apply(lambda x: dt.datetime.strptime(x,'%Y-%m-%d %H:%M:%S') )
btc['Date'] = btc['Date'].dt.date

# %%
btc['Returns'] = btc['Close Price'].diff()

# %%
btc.head()
# Out:
#          Date  Close Price  Returns
# 0  2010-07-18         0.09      NaN
# 1  2010-07-19         0.08    -0.01
# 2  2010-07-20         0.07    -0.01
# 3  2010-07-21         0.08     0.01
# 4  2010-07-22         0.05    -0.03

# %%
data = df.merge(btc, how='left', on='Date')

# %%
df.shape
# Out:
# (1045025, 2)

# %%
btc.shape
# Out:
# (2789, 3)

# %%
data.shape
# Out:
# (1045025, 4)

# %%
data.head() # Merged dataset
# Out:
#                                                 Text        Date  Close Price  \
# 0  The price of bitcoin on @coinbase is now 673.6...  2016-10-27       686.52
# 1  RT @RedditBTC: Iceland: Few days before electi...  2016-10-27       686.52
# 2  Easy and easy and easy mining #bitcoin with cl...  2016-10-27       686.52
# 3  Bitcoin based social media community, Yours, c...  2016-10-27       686.52
# 4  RT @BitcoinMagazine: With TumbleBit, #Bitcoin ...  2016-10-27       686.52
#
#    Returns
# 0    12.16
# 1    12.16
# 2    12.16
# 3    12.16
# 4    12.16

# %% [markdown]
# ## Clean twitter data

# %%
def beautify_tweet(raw_tweet):
    tweet_text = BeautifulSoup(raw_tweet, "lxml").get_text()
    letters_only = re.sub("[^a-zA-Z]"," ", tweet_text)
    words = letters_only.lower().split()
    meaningful_words = [w for w in words if not w in stopwords.words("english")]
    return( " ".join( meaningful_words ))

# %%
data['Text'] = data['Text'].apply( lambda x: beautify_tweet(x))

# %%
"""for idx, row in data.iterrows():
    analysis = TextBlob(row['Text'])
    row ['Sentiment Score'] = analysis.sentiment.polarity
    if analysis.sentiment.polarity > 0:
        row['Sentiment'] =  1 # positive
    elif analysis.sentiment.polarity == 0:
        row['Sentiment'] =  0 # neutral
    else:
        row['Sentiment'] = -1 # negative"""

# %% [markdown]
# ## Import Google trends data

# %%
gtrends = pd.read_csv('gtrends_bitcoin_buysell.csv')

# %%
gtrends.drop('Unnamed: 0',axis=1,inplace=True)

# %%
gtrends.head()
# Out:
#          Date  Gtrends Buy  Gtrends Sell
# 0  2016-10-27          100            20
# 1  2016-10-28          198            33
# 2  2016-10-29          152            39
# 3  2016-10-30          188            23
# 4  2016-10-31          193            16

# %%
gtrends['Date'] = gtrends['Date'].apply(lambda x: dt.datetime.strptime(x,'%Y-%m-%d') )
gtrends['Date'] = gtrends['Date'].dt.date

# %% [markdown]
# ## Sentiment analysis

# %%
def sentiment_score(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# %%
data['Sentiment Score'] = data['Text'].apply(lambda x: sentiment_score(x))

# %%
df = data.merge(gtrends, how='left', on='Date')

# %%
data['Date'].iloc[0]
# Out:
# datetime.date(2016, 10, 27)

# %%
gtrends['Date'].iloc[0]
# Out:
# datetime.date(2016, 10, 27)

# %%
df.head()
# Out:
#                                                 Text        Date  Close Price  \
# 0  The price of bitcoin on @coinbase is now 673.6...  2016-10-27       686.52
# 1  RT @RedditBTC: Iceland: Few days before electi...  2016-10-27       686.52
# 2  Easy and easy and easy mining #bitcoin with cl...  2016-10-27       686.52
# 3  Bitcoin based social media community, Yours, c...  2016-10-27       686.52
# 4  RT @BitcoinMagazine: With TumbleBit, #Bitcoin ...  2016-10-27       686.52
#
#    Returns  Sentiment Score  Gtrends Buy  Gtrends Sell
# 0    12.16         0.000000          100            20
# 1    12.16        -0.200000          100            20
# 2    12.16         0.433333          100            20
# 3    12.16         0.033333          100            20
# 4    12.16         0.500000          100            20

# %%
#df.drop('Close Price', axis=1, inplace=True)

# %%
df.drop('Text', axis=1, inplace=True)

# %%
df = df.merge(btc, how='left', on='Date')

# %%
df.head()
# Out:
#          Date  Returns_x  Sentiment Score  Gtrends Buy  Gtrends Sell  \
# 0  2016-10-27      12.16         0.000000          100            20
# 1  2016-10-27      12.16        -0.200000          100            20
# 2  2016-10-27      12.16         0.433333          100            20
# 3  2016-10-27      12.16         0.033333          100            20
# 4  2016-10-27      12.16         0.500000          100            20
#
#    Close Price  Returns_y
# 0       686.52      12.16
# 1       686.52      12.16
# 2       686.52      12.16
# 3       686.52      12.16
# 4       686.52      12.16

# %%
sentiment = pd.DataFrame(df.groupby('Date').mean()['Sentiment Score']).reset_index()

# %%
master = sentiment.merge(gtrends, on='Date', how='left')

# %%
master = master.merge(btc, on='Date', how='left')

# %%
master.head()
# Out:
#          Date  Sentiment Score  Gtrends Buy  Gtrends Sell  Close Price  \
# 0  2016-10-27         0.074786          100            20       686.52
# 1  2016-10-28         0.099824          198            33       688.10
# 2  2016-10-29         0.089142          152            39       712.87
# 3  2016-10-30         0.095448          188            23       696.35
# 4  2016-10-31         0.097629          193            16       697.37
#
#    Returns
# 0    12.16
# 1     1.58
# 2    24.77
# 3   -16.52
# 4     1.02

# %%
#master.to_csv('master.csv')

# %%
#master = pd.read_csv('master.csv')

# %%
#master.drop(['Date','Close Price'],axis=1, inplace=True)

# %%
master.head()
# Out:
#    Unnamed: 0        Date  Sentiment Score  Gtrends Buy  Gtrends Sell  \
# 0           0  2016-10-27         0.074786          100            20
# 1           1  2016-10-28         0.099824          198            33
# 2           2  2016-10-29         0.089142          152            39
# 3           3  2016-10-30         0.095448          188            23
# 4           4  2016-10-31         0.097629          193            16
#
#    Close Price  Returns
# 0       686.52    12.16
# 1       688.10     1.58
# 2       712.87    24.77
# 3       696.35   -16.52
# 4       697.37     1.02

# %%
master.describe()
# Out:
#        Unnamed: 0  Sentiment Score  Gtrends Buy  Gtrends Sell  Close Price  \
# count  119.000000       119.000000   119.000000    119.000000   119.000000
# mean    59.000000         0.091259   183.453782     27.789916   855.180504
# std     34.496377         0.015483    20.398051     10.306222   124.644079
# min      0.000000         0.043132   100.000000      5.000000   686.520000
# 25%     29.500000         0.080265   176.000000     20.500000   742.040000
# 50%     59.000000         0.093186   192.000000     27.000000   826.120000
# 75%     88.500000         0.101179   198.500000     34.000000   967.950000
# max    118.000000         0.128099   200.000000     58.000000  1129.870000
#
#           Returns
# count  119.000000
# mean     3.763277
# std     28.431757
# min   -128.810000
# 25%     -4.495000
# 50%      5.090000
# 75%     13.480000
# max     99.050000

# %% [markdown]
# ## Import S&P data

# %%
snp = pd.read_csv('GSPC_.csv')

# %%
snp.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2016-10-27  2144.060059  2147.129883  2132.520020  2133.040039
# 1  2016-10-28  2132.229980  2140.719971  2119.360107  2126.409912
# 2  2016-10-31  2129.780029  2133.250000  2125.530029  2126.149902
# 3  2016-11-01  2128.679932  2131.449951  2097.850098  2111.719971
# 4  2016-11-02  2109.429932  2111.760010  2094.000000  2097.939941
#
#      Adj Close      Volume
# 0  2133.040039  4204830000
# 1  2126.409912  4019510000
# 2  2126.149902  3922400000
# 3  2111.719971  4532160000
# 4  2097.939941  4248580000

# %%
snp = snp[['Date','Close']]

# %%
#snp['Date'] = snp['Date'].apply(lambda x: dt.datetime.strptime(x,'%m-%d-%Y') )
#snp['Date'] = snp['Date'].dt.date

# %%
snp.head()
# Out:
#          Date        Close
# 0  2016-10-27  2133.040039
# 1  2016-10-28  2126.409912
# 2  2016-10-31  2126.149902
# 3  2016-11-01  2111.719971
# 4  2016-11-02  2097.939941

# %%
master.head()
# Out:
#    Unnamed: 0        Date  Sentiment Score  Gtrends Buy  Gtrends Sell  \
# 0           0  2016-10-27         0.074786          100            20
# 1           1  2016-10-28         0.099824          198            33
# 2           2  2016-10-29         0.089142          152            39
# 3           3  2016-10-30         0.095448          188            23
# 4           4  2016-10-31         0.097629          193            16
#
#    Close Price  Returns
# 0       686.52    12.16
# 1       688.10     1.58
# 2       712.87    24.77
# 3       696.35   -16.52
# 4       697.37     1.02

# %%
master = master.merge(snp, how='left',on='Date')

# %%
snp['Date'].iloc[0]
# Out:
# '2016-10-27'

# %%
master.head()
# Out:
#    Unnamed: 0        Date  Sentiment Score  Gtrends Buy  Gtrends Sell  \
# 0           0  2016-10-27         0.074786          100            20
# 1           1  2016-10-28         0.099824          198            33
# 2           2  2016-10-29         0.089142          152            39
# 3           3  2016-10-30         0.095448          188            23
# 4           4  2016-10-31         0.097629          193            16
#
#    Close Price  Returns        Close
# 0       686.52    12.16  2133.040039
# 1       688.10     1.58  2126.409912
# 2       712.87    24.77          NaN
# 3       696.35   -16.52          NaN
# 4       697.37     1.02  2126.149902

# %%
master.columns = ['Date','Avg Sentiment Score','Gtrends Buy','Gtrends Sell','BTC close price','BTC Returns','S&P close price']

# %%
master.to_csv('master.csv')

# %%
master = pd.read_csv('master.csv')

# %%
master.head()
# Out:
#    Unnamed: 0        Date  Avg Sentiment Score  Gtrends Buy  Gtrends Sell  \
# 0           0  2016-10-27             0.077948          100            20
# 1           1  2016-10-28             0.095330          198            33
# 2           2  2016-10-29             0.082904          152            39
# 3           3  2016-10-30             0.091768          188            23
# 4           4  2016-10-31             0.090879          193            16
#
#    BTC close price  BTC Returns  S&P close price
# 0           686.52        12.16      2133.040039
# 1           688.10         1.58      2126.409912
# 2           712.87        24.77              NaN
# 3           696.35       -16.52              NaN
# 4           697.37         1.02      2126.149902

# %%
master.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# Imputing missing S&P500 prices in the 'Close' column

# %%
for i in range(len(master)):
    if np.isnan(master['Close'][i]):
        master['Close'][i] = master['Close'][i-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-3dadc2b49f10> in <module>()
#       1 for i in range(len(master)):
# ----> 2     if np.isnan(master['Close'][i]):
#       3         master['Close'][i] = master['Close'][i-1]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'

# %%
master.head()
# Out:
#    Unnamed: 0        Date  Sentiment Score  Gtrends Buy  Gtrends Sell  \
# 0           0  2016-10-27         0.074786          100            20
# 1           1  2016-10-28         0.099824          198            33
# 2           2  2016-10-29         0.089142          152            39
# 3           3  2016-10-30         0.095448          188            23
# 4           4  2016-10-31         0.097629          193            16
#
#    Close Price  Returns        Close
# 0       686.52    12.16  2133.040039
# 1       688.10     1.58  2126.409912
# 2       712.87    24.77  2126.409912
# 3       696.35   -16.52  2126.409912
# 4       697.37     1.02  2126.149902

# %%
master.drop('Unnamed: 0',axis=1,inplace=True)

# %%
master.head()
# Out:
#          Date  Sentiment Score  Gtrends Buy  Gtrends Sell  Close Price  \
# 0  2016-10-27         0.074786          100            20       686.52
# 1  2016-10-28         0.099824          198            33       688.10
# 2  2016-10-29         0.089142          152            39       712.87
# 3  2016-10-30         0.095448          188            23       696.35
# 4  2016-10-31         0.097629          193            16       697.37
#
#    Returns        Close
# 0    12.16  2133.040039
# 1     1.58  2126.409912
# 2    24.77  2126.409912
# 3   -16.52  2126.409912
# 4     1.02  2126.149902

# %%
master['Prev_bitcoin_price'] = master['Close Price']
for i in range(len(master)):
    if i!=0:
        master['Prev_bitcoin_price'][i] = master['Close Price'][i-1]
# Out:
# C:\Users\kapilesh\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
master.head()
# Out:
#          Date  Sentiment Score  Gtrends Buy  Gtrends Sell  Close Price  \
# 0  2016-10-27         0.074786          100            20       686.52
# 1  2016-10-28         0.099824          198            33       688.10
# 2  2016-10-29         0.089142          152            39       712.87
# 3  2016-10-30         0.095448          188            23       696.35
# 4  2016-10-31         0.097629          193            16       697.37
#
#    Returns        Close  Prev_bitcoin_price
# 0    12.16  2133.040039              686.52
# 1     1.58  2126.409912              686.52
# 2    24.77  2126.409912              688.10
# 3   -16.52  2126.409912              712.87
# 4     1.02  2126.149902              696.35

# %% [markdown]
# ## EDA

# %%
X = master.iloc[:, [1,2,3,6,7]]
Y = master.iloc[:, 4]

# %%
X.head()
# Out:
#    Sentiment Score  Gtrends Buy  Gtrends Sell        Close  Prev_bitcoin_price
# 0         0.074786          100            20  2133.040039              686.52
# 1         0.099824          198            33  2126.409912              686.52
# 2         0.089142          152            39  2126.409912              688.10
# 3         0.095448          188            23  2126.409912              712.87
# 4         0.097629          193            16  2126.149902              696.35

# %%
X.hist(figsize=(10,10))
plt.show()

# %%
X.plot()
plt.show()

# %%
sns.pairplot(X,diag_kind='kde')
plt.show()

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(15,15))
plt.title('Correlation of Features', y=1.05, size=15)
sns.heatmap(X.astype(float).corr().round(2)\
            ,linewidths=0.1, square=True,vmax=1.0, cmap=colormap, linecolor='white', annot=True)
plt.show()

# %% [markdown]
# ## Normalize data

# %%
#Not using date and returns as features

# %%
x = X.values
y = Y.values

# %%
from sklearn import preprocessing

#x = master.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled)

# %%
df.columns = X.columns
#df.columns = master.columns[[1,2,3,6,7]]

# %%
df.head()
# Out:
#    Sentiment Score  Gtrends Buy  Gtrends Sell     Close  Prev_bitcoin_price
# 0         0.372538         0.00      0.283019  0.170807            0.000000
# 1         0.667220         0.98      0.528302  0.147145            0.000000
# 2         0.541501         0.52      0.641509  0.147145            0.003564
# 3         0.615725         0.88      0.339623  0.147145            0.059434
# 4         0.641389         0.93      0.207547  0.146217            0.022172

# %%
df.describe()
# Out:
#        Sentiment Score  Gtrends Buy  Gtrends Sell       Close  \
# count       119.000000   119.000000    119.000000  119.000000
# mean          0.566420     0.834538      0.429998    0.559739
# std           0.182223     0.203981      0.194457    0.234542
# min           0.000000     0.000000      0.000000    0.000000
# 25%           0.437023     0.760000      0.292453    0.404408
# 50%           0.589095     0.920000      0.415094    0.631157
# 75%           0.683178     0.985000      0.547170    0.687884
# max           1.000000     1.000000      1.000000    1.000000
#
#        Prev_bitcoin_price
# count          119.000000
# mean             0.372165
# std              0.277713
# min              0.000000
# 25%              0.124698
# 50%              0.306530
# 75%              0.626029
# max              1.000000

# %%
df.plot()
plt.show()

# %% [markdown]
# ## Modeling

# %%
len(df)
# Out:
# 119

# %%
# Splitting the dataset into the Training set and Test set (80/20)
# Reserving the latest 20% data for test
x_train = df.iloc[:94,:]
x_test = df.iloc[95:,:]
y_train = y[:94]
y_test = y[95:]

#x_train, x_test, y_train, y_test = train_test_split(df, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.ensemble import GradientBoostingRegressor

# %%
mod1 = LinearRegression()
mod1.fit(x_train, y_train)
# Predicting the Test set results
y_pred = mod1.predict(x_test)

# %%
y_pred_train = mod1.predict(x_train)
# The mean squared error
print("Mean squared error on training set:",np.mean((y_pred_train - y_train) ** 2))
print("Mean squared error on test set:",np.mean((y_pred - y_test) ** 2))
# Out:
# Mean squared error on training set: 811.830051021391
# Mean squared error on test set: 636.8986433722641

# %%
plt.plot(pd.to_datetime(master.iloc[95:119,0]), y_pred, c='green')
plt.plot(pd.to_datetime(master.iloc[95:119,0]), y_test, c='blue')
plt.xticks(rotation=30)
plt.title('Predicted bitcoin price vs actual price (Linear regression)')
plt.xlabel('Date')
plt.ylabel('Bitcoin price (US$)')
plt.show()

# %%
#Decision tree regressor
mod2 = DecisionTreeRegressor(random_state=0)
mod2.fit(x_train, y_train)
pred_mod2 = mod2.predict(x_test)
pred_mod2_train = mod2.predict(x_train)
# The mean squared error
print("Mean squared error on training set:",np.mean((pred_mod2_train - y_train) ** 2))
print("Mean squared error on test set:",np.mean((pred_mod2 - y_test) ** 2))
# Out:
# Mean squared error on training set: 0.0
# Mean squared error on test set: 15685.759333333344

# %%
plt.plot(pd.to_datetime(master.iloc[95:119,0]), pred_mod2, c='green')
plt.plot(pd.to_datetime(master.iloc[95:119,0]), y_test, c='blue')
plt.xticks(rotation=30)
plt.title('Predicted bitcoin price vs actual price (Decision tree)')
plt.xlabel('Date')
plt.ylabel('Bitcoin price (US$)')
plt.show()

# %%
# Feature importance function

def plot_model_var_imp( model , X , y ):
    imp = pd.DataFrame( 
        model.feature_importances_  , 
        columns = [ 'Importance' ] , 
        index = X.columns 
    )
    imp = imp.sort_values( [ 'Importance' ] , ascending = True )
    imp[ : 10 ].plot( kind = 'barh' )
    plt.xlabel('Importance Factor')
    plt.ylabel('Features')
    plt.title('Feature importance chart')
    plt.show()
    #print ('Training accuracy:',model.score( X , y ))

# %%
#Feature importance chart for decision tree
plot_model_var_imp(mod2, x_train, y_train)

# %%
#Random Forest regressor
mod3 = RandomForestRegressor(max_depth=2, random_state=0)
mod3.fit(x_train, y_train)
pred_mod3 = mod3.predict(x_test)
pred_mod3_train = mod3.predict(x_train)
# The mean squared error
print("Mean squared error on training set:",np.mean((pred_mod3_train - y_train) ** 2))
print("Mean squared error on test set:",np.mean((pred_mod3 - y_test) ** 2))
# Out:
# Mean squared error on training set: 698.628990029417
# Mean squared error on test set: 3545.8870585883274

# %%
plt.plot(pd.to_datetime(master.iloc[95:119,0]), pred_mod3, c='green')
plt.plot(pd.to_datetime(master.iloc[95:119,0]), y_test, c='blue')
plt.xticks(rotation=30)
plt.title('Predicted bitcoin price vs actual price (Random Forest)')
plt.xlabel('Date')
plt.ylabel('Bitcoin price (US$)')
plt.show()

# %%
#Feature importance chart for random forest
plot_model_var_imp(mod3, x_train, y_train)

# %%
#Gradient boosting regression
mod4 = GradientBoostingRegressor()
mod4.fit(x_train, y_train)
pred_mod4 = mod4.predict(x_test)
pred_mod4_train = mod4.predict(x_train)
# The mean squared error
print("Mean squared error on training set:",np.mean((pred_mod4_train - y_train) ** 2))
print("Mean squared error on test set:",np.mean((pred_mod4 - y_test) ** 2))
# Out:
# Mean squared error on training set: 15.482734938522626
# Mean squared error on test set: 6039.206102029418

# %%
plt.plot(pd.to_datetime(master.iloc[95:119,0]), pred_mod4, c='green')
plt.plot(pd.to_datetime(master.iloc[95:119,0]), y_test, c='blue')
plt.xticks(rotation=30)
plt.title('Predicted bitcoin price vs actual price (Gradient Boosting)')
plt.xlabel('Date')
plt.ylabel('Bitcoin price (US$)')
plt.show()

# %%
#Feature importance chart for boosting
plot_model_var_imp(mod4, x_train, y_train)
